# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

def mean_num(num):
    return sum(num) / len(num)
mean_num([1,2,3,4])
# Out:
# 2.5

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
import math
def variance(num):
    n = len(num)
    deviations = [(x - mean_num(num)) ** 2 for x in num]
    var = sum(deviations) / n
    return var

def std_dev(num):
    var = variance(num)
    std_dev = math.sqrt(var)
    return std_dev
    
std_dev([1,2,3,4])
# Out:
# 1.118033988749895

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
30.5 / 100
# Out:
# 0.305

# %%
# Code:
def pct_to_dec(num):
    return float(num[:-1]) / 100
pct_to_dec('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

ca_act = pd.read_csv('../data/act_2019_ca.csv')
ca_sat = pd.read_csv('../data/sat_2019_ca.csv')
ca_act.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 0  3.366993e+13   33.0  3366993.0   129882.0     S
# 1  1.964212e+13   19.0  1964212.0  1995596.0     S
# 2  1.563776e+13   15.0  1563776.0  1530377.0     S
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
#
#                              SName                  DName        CName  \
# 0  21st Century Learning Institute       Beaumont Unified    Riverside
# 1      ABC Secondary (Alternative)            ABC Unified  Los Angeles
# 2      Abraham Lincoln Alternative  Southern Kern Unified         Kern
# 3             Abraham Lincoln High       San Jose Unified  Santa Clara
# 4      Abraham Lincoln Senior High    Los Angeles Unified  Los Angeles
#
#    Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21  \
# 0      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 1      58.0         0.0        NaN       NaN        NaN       NaN     NaN
# ...

# %%
# 2. Check for missing values
ca_act.isnull().sum()
# Out:
# CDS               1
# CCode             1
# CDCode            1
# SCode           523
# RType             1
# SName           581
# DName            59
# CName             1
# Enroll12          1
# NumTstTakr        1
# AvgScrRead      357
# AvgScrEng       357
# AvgScrMath      357
# AvgScrSci       357
# NumGE21         357
# PctGE21         357
# Year              1
# Unnamed: 17    2310
# dtype: int64

# %%
# 3. Check for any obvious issues with the observations 
# (keep in mind the minimum & maximum possible values for each test/subtest).
ca_act.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CDS          2309 non-null   float64
#  1   CCode        2309 non-null   float64
#  2   CDCode       2309 non-null   float64
#  3   SCode        1787 non-null   float64
#  4   RType        2309 non-null   object
#  5   SName        1729 non-null   object
#  6   DName        2251 non-null   object
#  7   CName        2309 non-null   object
#  8   Enroll12     2309 non-null   float64
#  9   NumTstTakr   2309 non-null   float64
#  10  AvgScrRead   1953 non-null   object
#  11  AvgScrEng    1953 non-null   object
#  12  AvgScrMath   1953 non-null   object
#  13  AvgScrSci    1953 non-null   object
#  14  NumGE21      1953 non-null   object
#  15  PctGE21      1953 non-null   object
#  16  Year         2309 non-null   object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
# 4. Fix any errors you identified in steps 2-3.
# ca_act.drop(columns=['Unnamed: 17'], inplace=True) #dropped last column
ca_act['AvgScrRead'].sort_values(ascending=True) # multiple checks for wird values. Columns below had '*' and 'N/A' and values stored as string (object)
replace_col = ['AvgScrRead', 'AvgScrEng', 'AvgScrMath', 'AvgScrSci', 'NumGE21', 'PctGE21']
ca_act[replace_col] = ca_act[replace_col].replace({'*':np.nan, 'N/A':np.nan}) #replaced 
ca_act['NumGE21'].sort_values(ascending=False)
# Out:
# 1107    993
# 2093     99
# 1143     99
# 1502     98
# 2272     98
#        ...
# 2304    NaN
# 2305    NaN
# 2307    NaN
# 2308    NaN
# 2309    NaN
# Name: NumGE21, Length: 2310, dtype: object

# %%
ca_act.info(); #11-15 needs to be float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CDS          2309 non-null   float64
#  1   CCode        2309 non-null   float64
#  2   CDCode       2309 non-null   float64
#  3   SCode        1787 non-null   float64
#  4   RType        2309 non-null   object
#  5   SName        1729 non-null   object
#  6   DName        2251 non-null   object
#  7   CName        2309 non-null   object
#  8   Enroll12     2309 non-null   float64
#  9   NumTstTakr   2309 non-null   float64
#  10  AvgScrRead   1421 non-null   object
#  11  AvgScrEng    1421 non-null   object
#  12  AvgScrMath   1421 non-null   object
#  13  AvgScrSci    1421 non-null   object
#  14  NumGE21      1421 non-null   object
#  15  PctGE21      1421 non-null   object
#  16  Year         2309 non-null   object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
ca_act['PctGE21'].unique()
ca_act[replace_col] = ca_act[replace_col].astype(float) # converting to float
ca_act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CDS          2309 non-null   float64
#  1   CCode        2309 non-null   float64
#  2   CDCode       2309 non-null   float64
#  3   SCode        1787 non-null   float64
#  4   RType        2309 non-null   object
#  5   SName        1729 non-null   object
#  6   DName        2251 non-null   object
#  7   CName        2309 non-null   object
#  8   Enroll12     2309 non-null   float64
#  9   NumTstTakr   2309 non-null   float64
#  10  AvgScrRead   1421 non-null   float64
#  11  AvgScrEng    1421 non-null   float64
#  12  AvgScrMath   1421 non-null   float64
#  13  AvgScrSci    1421 non-null   float64
#  14  NumGE21      1421 non-null   float64
#  15  PctGE21      1421 non-null   float64
#  16  Year         2309 non-null   object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
# 5. Display the data types of each feature.
ca_act.dtypes
# Out:
# CDS            float64
# CCode          float64
# CDCode         float64
# SCode          float64
# RType           object
# SName           object
# DName           object
# CName           object
# Enroll12       float64
# NumTstTakr     float64
# AvgScrRead     float64
# AvgScrEng      float64
# AvgScrMath     float64
# AvgScrSci      float64
# NumGE21        float64
# PctGE21        float64
# Year            object
# Unnamed: 17    float64
# dtype: object

# %%
# 6. Fix any incorrect data types found in step 5.
# Fix any individual values preventing other columns from being the appropriate type.
# If your dataset has a column of percents (ex. '50%', '30.5%', etc.),
# use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats!
# Hint: use .map() or .apply().


# Fixed in step 5.

# %%
ca_act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CDS          2309 non-null   float64
#  1   CCode        2309 non-null   float64
#  2   CDCode       2309 non-null   float64
#  3   SCode        1787 non-null   float64
#  4   RType        2309 non-null   object
#  5   SName        1729 non-null   object
#  6   DName        2251 non-null   object
#  7   CName        2309 non-null   object
#  8   Enroll12     2309 non-null   float64
#  9   NumTstTakr   2309 non-null   float64
#  10  AvgScrRead   1421 non-null   float64
#  11  AvgScrEng    1421 non-null   float64
#  12  AvgScrMath   1421 non-null   float64
#  13  AvgScrSci    1421 non-null   float64
#  14  NumGE21      1421 non-null   float64
#  15  PctGE21      1421 non-null   float64
#  16  Year         2309 non-null   object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
# 7. Rename Columns.
# Column names should be all lowercase.
# Column names should not contain spaces (underscores will suffice--this allows for using the df.column_name
# method to access columns in addition to df['column_name']).
# Column names should be unique and informative.

act_replace_dict = {
    'CDS': 'unique_id',
    'CCode': 'county_code',
    'CDCode': 'district_code',
    'SCode': 'school_code',
    'SName': 'school_name',
    'DName': 'district_name',
    'CName': 'county_name',
    'Enroll12': 'enrolled_num',
    'NumTstTakr': 'num_takers',
    'AvgScrRead': 'avg_read',
    'AvgScrEng': 'avg_eng',
    'AvgScrMath': 'avg_math',
    'AvgScrSci': 'avg_science',
    'NumGE21': 'num_above_bm',
    'PctGE21': 'pct_of_bm',
    'Year': 'year',
    'RType': 'record_type'
}

# %%
ca_act.rename(columns=act_replace_dict, inplace=True)

# %%
ca_act.head()
# Out:
#       unique_id  county_code  district_code  school_code record_type  \
# 0  3.366993e+13         33.0      3366993.0     129882.0           S
# 1  1.964212e+13         19.0      1964212.0    1995596.0           S
# 2  1.563776e+13         15.0      1563776.0    1530377.0           S
# 3  4.369666e+13         43.0      4369666.0    4333795.0           S
# 4  1.964733e+13         19.0      1964733.0    1935121.0           S
#
#                        school_name          district_name  county_name  \
# 0  21st Century Learning Institute       Beaumont Unified    Riverside
# 1      ABC Secondary (Alternative)            ABC Unified  Los Angeles
# 2      Abraham Lincoln Alternative  Southern Kern Unified         Kern
# 3             Abraham Lincoln High       San Jose Unified  Santa Clara
# 4      Abraham Lincoln Senior High    Los Angeles Unified  Los Angeles
#
#    enrolled_num  num_takers  avg_read  avg_eng  avg_math  avg_science  \
# ...

# %%
act_drop = [
    'unique_id',
    'county_code',
    'school_code',
    'school_name',
    'county_name',
    'avg_read',
    'avg_eng',
    'avg_math',
    'avg_science',
    'num_above_bm',
    'year',
    'Unnamed: 17'
]

# %%
# 8. Drop unnecessary rows (if needed).
ca_act.drop(columns=act_drop, inplace=True)

# %%
ca_act.head()
# Out:
#    district_code record_type          district_name  enrolled_num  num_takers  \
# 0      3366993.0           S       Beaumont Unified          18.0         0.0
# 1      1964212.0           S            ABC Unified          58.0         0.0
# 2      1563776.0           S  Southern Kern Unified          18.0         0.0
# 3      4369666.0           S       San Jose Unified         463.0        53.0
# 4      1964733.0           S    Los Angeles Unified         226.0        19.0
#
#    pct_of_bm
# 0        NaN
# 1        NaN
# 2        NaN
# 3      64.15
# 4      57.89

# %%
ca_act['record_type'].unique() # lookup unique vaules in Record Type
# Out:
# array(['S', 'C', 'D', 'X', nan], dtype=object)

# %%
ca_act.groupby('record_type').head() # Can drop all County ('C'), School ('S') and State ('X') records: just need Districts
# Out:
#       district_code record_type                       district_name  \
# 0         3366993.0           S                    Beaumont Unified
# 1         1964212.0           S                         ABC Unified
# 2         1563776.0           S               Southern Kern Unified
# 3         4369666.0           S                    San Jose Unified
# 4         1964733.0           S                 Los Angeles Unified
# 1064            0.0           C                                 NaN
# 1065            0.0           C                                 NaN
# 1066            0.0           C                                 NaN
# 1067            0.0           C                                 NaN
# 1068            0.0           C                                 NaN
# 1122       110017.0           D  Alameda County Office of Education
# 1123       161119.0           D                     Alameda Unified
# 1124       161127.0           D                 Albany City Unified
# ...

# %%
ca_act = ca_act[ca_act.record_type == 'D']

# %%
ca_act.head()
# Out:
#       district_code record_type                       district_name  \
# 1122       110017.0           D  Alameda County Office of Education
# 1123       161119.0           D                     Alameda Unified
# 1124       161127.0           D                 Albany City Unified
# 1125       161143.0           D                    Berkeley Unified
# 1126       161150.0           D               Castro Valley Unified
#
#       enrolled_num  num_takers  pct_of_bm
# 1122         170.0         0.0        NaN
# 1123         919.0       155.0      86.45
# 1124         307.0        58.0      87.93
# 1125         820.0       227.0      73.13
# 1126         737.0       106.0      77.36

# %%
ca_act['pct_part'] = ca_act['num_takers'] / ca_act['enrolled_num']

# %%
ca_act.reset_index(drop=True)
# Out:
#      district_code record_type                       district_name  \
# 0         110017.0           D  Alameda County Office of Education
# 1         161119.0           D                     Alameda Unified
# 2         161127.0           D                 Albany City Unified
# 3         161143.0           D                    Berkeley Unified
# 4         161150.0           D               Castro Valley Unified
# ..             ...         ...                                 ...
# 517      5772710.0           D              Woodland Joint Unified
# 518      5810587.0           D     Yuba County Office of Education
# 519      5872728.0           D             Camptonville Elementary
# 520      5872736.0           D            Marysville Joint Unified
# 521      5872769.0           D                Wheatland Union High
#
#      enrolled_num  num_takers  pct_of_bm  pct_part
# 0           170.0         0.0        NaN  0.000000
# 1           919.0       155.0      86.45  0.168662
# ...

# %%
# some Districts have no ACT test takers, removing from list. Might re-add from SAT dataframe.
ca_act = ca_act[ca_act.pct_of_bm.notnull()]

# %%
ca_act # ACT done!
# Out:
#       district_code record_type             district_name  enrolled_num  \
# 1123       161119.0           D           Alameda Unified         919.0
# 1124       161127.0           D       Albany City Unified         307.0
# 1125       161143.0           D          Berkeley Unified         820.0
# 1126       161150.0           D     Castro Valley Unified         737.0
# 1128       161176.0           D           Fremont Unified        2537.0
# ...             ...         ...                       ...           ...
# 1635      5772678.0           D       Davis Joint Unified         717.0
# 1637      5772694.0           D        Washington Unified         563.0
# 1639      5772710.0           D    Woodland Joint Unified         767.0
# 1642      5872736.0           D  Marysville Joint Unified         602.0
# 1643      5872769.0           D      Wheatland Union High         167.0
#
#       num_takers  pct_of_bm  pct_part
# 1123       155.0      86.45  0.168662
# ...

# %%
# link to ACT percentiles: https://blog.prepscholar.com/what-is-a-good-act-score-a-bad-act-score-an-excellent-act-score#:~:text=The%20average%20ACT%20score%20is,than%20%C2%BE%20of%20test%2Dtakers!

# %%
ca_sat.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# ...

# %%
ca_sat.isnull().sum() # Check for missing values
# Out:
# CDS                         1
# CCode                       1
# CDCode                      1
# SCode                       1
# RType                       1
# SName                     598
# DName                      59
# CName                       1
# Enroll12                    1
# NumTSTTakr12                1
# NumERWBenchmark12         276
# PctERWBenchmark12         276
# NumMathBenchmark12        276
# PctMathBenchmark12        276
# Enroll11                    1
# NumTSTTakr11                1
# NumERWBenchmark11         311
# PctERWBenchmark11         311
# NumMathBenchmark11        311
# PctMathBenchmark11        311
# TotNumBothBenchmark12     276
# PctBothBenchmark12        276
# TotNumBothBenchmark11     311
# PctBothBenchmark11        311
# Year                        1
# Unnamed: 25              2580
# dtype: int64

# %%
# drop columns
sat_drop_col = [
    'CDS',
    'CCode',
    'SCode',
    'SName',
    'CName',
    'NumERWBenchmark12',      
    'PctERWBenchmark12',         
    'NumMathBenchmark12',        
    'PctMathBenchmark12',        
    'Enroll11',                    
    'NumTSTTakr11',                
    'NumERWBenchmark11',         
    'PctERWBenchmark11',         
    'NumMathBenchmark11',        
    'PctMathBenchmark11',                
    'TotNumBothBenchmark12',
    'TotNumBothBenchmark11',     
    'PctBothBenchmark11',        
    'Year',                        
    'Unnamed: 25'             
]

# %%
ca_sat.drop(columns=sat_drop_col, inplace=True)

# %%
ca_sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CDCode              2579 non-null   float64
#  1   RType               2579 non-null   object
#  2   DName               2521 non-null   object
#  3   Enroll12            2579 non-null   float64
#  4   NumTSTTakr12        2579 non-null   float64
#  5   PctBothBenchmark12  2304 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 121.1+ KB

# %%
sat_replace_dict = {
    'CDCode': 'district_code',
    'RType': 'record_type',
    'DName': 'district_name',
    'Enroll12': 'enrolled_num',
    'NumTSTTakr12': 'num_takers',
    'TotNumBothBenchmark12': 'num_above_bm',
    'PctBothBenchmark12': 'pct_of_bm'
}

# %%
ca_sat.rename(columns=sat_replace_dict, inplace=True)

# %%
ca_sat = ca_sat[ca_sat.record_type == 'D']

# %%
ca_sat['pct_part'] = ca_sat['num_takers'] / ca_sat['enrolled_num']

# %%
ca_sat.info() #pct_of needs to be float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 539 entries, 2037 to 2575
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   district_code  539 non-null    float64
#  1   record_type    539 non-null    object
#  2   district_name  539 non-null    object
#  3   enrolled_num   539 non-null    float64
#  4   num_takers     539 non-null    float64
#  5   pct_of_bm      501 non-null    object
#  6   pct_part       536 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 33.7+ KB

# %%
ca_sat['pct_of_bm'].sort_values(ascending=True)
# Out:
# 2197      *
# 2317      *
# 2107      *
# 2106      *
# 2429      *
#        ...
# 2539    NaN
# 2540    NaN
# 2561    NaN
# 2572    NaN
# 2573    NaN
# Name: pct_of_bm, Length: 539, dtype: object

# %%
ca_sat['pct_of_bm'] = ca_sat['pct_of_bm'].map(lambda pct: np.nan if pct == '*' else float(pct))

# %%
ca_sat['pct_of_bm'].sort_values(ascending=True)
# Out:
# 2314    0.00
# 2215    0.00
# 2342    0.00
# 2100    0.00
# 2416    5.95
#         ...
# 2566     NaN
# 2570     NaN
# 2571     NaN
# 2572     NaN
# 2573     NaN
# Name: pct_of_bm, Length: 539, dtype: float64

# %%
ca_sat = ca_sat[ca_sat.pct_of_bm.notnull()]

# %%
ca_sat['pct_of_bm'].sort_values(ascending=True)
# Out:
# 2314     0.00
# 2215     0.00
# 2342     0.00
# 2100     0.00
# 2416     5.95
#         ...
# 2210    88.09
# 2405    90.46
# 2130    90.75
# 2075    91.67
# 2554    91.76
# Name: pct_of_bm, Length: 405, dtype: float64

# %%
ca_sat.reset_index(drop=True)
# Out:
#      district_code record_type                           district_name  \
# 0         161176.0           D                         Fremont Unified
# 1         161275.0           D                   Piedmont City Unified
# 2         161291.0           D                     San Leandro Unified
# 3        1062166.0           D                          Fresno Unified
# 4        1075127.0           D                         Mendota Unified
# ..             ...         ...                                     ...
# 400      3910397.0           D  San Joaquin County Office of Education
# 401      4469799.0           D                   Pajaro Valley Unified
# 402      4475432.0           D                   Scotts Valley Unified
# 403      5075556.0           D                       Riverbank Unified
# 404      5772678.0           D                     Davis Joint Unified
#
#      enrolled_num  num_takers  pct_of_bm  pct_part
# 0          2537.0       845.0      80.24  0.333071
# ...

# %% [markdown]
# SAT DONE! Combining:

# %%
act_sat = pd.concat([ca_act, ca_sat])
act_sat
# Out:
#       district_code record_type                           district_name  \
# 1123       161119.0           D                         Alameda Unified
# 1124       161127.0           D                     Albany City Unified
# 1125       161143.0           D                        Berkeley Unified
# 1126       161150.0           D                   Castro Valley Unified
# 1128       161176.0           D                         Fremont Unified
# ...             ...         ...                                     ...
# 2567      3910397.0           D  San Joaquin County Office of Education
# 2568      4469799.0           D                   Pajaro Valley Unified
# 2569      4475432.0           D                   Scotts Valley Unified
# 2574      5075556.0           D                       Riverbank Unified
# 2575      5772678.0           D                     Davis Joint Unified
#
#       enrolled_num  num_takers  pct_of_bm  pct_part
# ...

# %% [markdown]
# Removing duplicates from both tables, combining numerical values into one by using mean:

# %%
# learned from https://stackoverflow.com/questions/46773467/how-to-aggregate-only-the-numerical-columns-in-a-mixed-dtypes-dataframe
final_df = act_sat.groupby(list(act_sat.select_dtypes(exclude=[np.number]))).agg(np.mean).reset_index()
final_df.head()
# Out:
#   record_type                       district_name  district_code  \
# 0           D                         ABC Unified      1964212.0
# 1           D                 Acalanes Union High       761630.0
# 2           D            Acton-Agua Dulce Unified      1975309.0
# 3           D  Alameda County Office of Education       110017.0
# 4           D                     Alameda Unified       161119.0
#
#    enrolled_num  num_takers  pct_of_bm  pct_part
# 0        1663.0       423.5     71.750  0.254660
# 1        1408.0       506.0     86.720  0.359375
# 2        1268.0       112.0     27.680  0.088328
# 3         170.0        67.0     16.420  0.394118
# 4         919.0       264.0     72.985  0.287269

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |district_code|object|Aggregate|Unique code for school district, shared between ACT & SAT|
# |record_type|object|Aggregate|record types: School, District, State|
# |district_name|object|Aggregate|school district name|
# |enrolled_num|float|Aggregate|number of stidents enrolled in 12th grade|
# |num_takers|float|Aggregate|number of students taking either ACT or SAT test|
# |pct_of_bm|float|Aggregate|percentage of students wit hresults above benchmark for either ACT or SAT|
# |pct_part|float|Aggregate|participation percantage|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
std_dev(combined_df['enrolled_num'])
# Out:
# 2420.506698087688

# %%
#Code:
"""keys = ['enrolled_num',
         'num_takers',
         'pct_of_bm',
         'pct_part'] # list of keys
values = """

sd = {col.name:std_dev(col) for col in [combined_df[i] for i in combined_df.columns if (combined_df[i].dtype=='float64') or (combined_df[i].dtype=='int64')]} # list of values per https://stackoverflow.com/questions/55048445/dictionary-comprehension-to-apply-a-function-to-dataframe-columns

# %%
sd
# Out:
# {'district_code': 1513563.9027154027,
#  'enrolled_num': 2420.506698087688,
#  'num_takers': 800.308226121846,
#  'pct_of_bm': 21.649428191685452,
#  'pct_part': 0.1415548723594336}

# %% [markdown]
# Identifying school districts with lowest %s over benchmark:

# %%
final_df = combined_df.sort_values('pct_of_bm', ascending=True).reset_index(drop=True)

# %%
final_df
# Out:
#     record_type                        district_name  district_code  \
# 0             D                Golden Plains Unified      1075234.0
# 1             D      Inyo County Office of Education      1410140.0
# 2             D                     Williams Unified       661622.0
# 3             D         Tulelake Basin Joint Unified      2573593.0
# 4             D         Firebaugh-Las Deltas Unified      1073809.0
# ..          ...                                  ...            ...
# 406           D                     Oak Park Unified      5673874.0
# 407           D                   Fremont Union High      4369468.0
# 408           D                   San Marino Unified      1964964.0
# 409           D                    La Canada Unified      1964659.0
# 410           D  Los Gatos-Saratoga Joint Union High      4369534.0
#
#      enrolled_num  num_takers  pct_of_bm  pct_part
# 0           125.0        23.0      0.000  0.184000
# ...

# %% [markdown]
# FINAL LIST: Combined ACT and SAT dataframes with unique School Distrcit entries, sorted by %s above benchmark, from lowest to highest

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %% [markdown]
# Determinining potential corelation between column values

# %%
# from: https://seaborn.pydata.org/examples/many_pairwise_correlations.html
# Compute the correlation matrix
corr = final_df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(130, 1300, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, annot=True, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %% [markdown]
# Obvious finding: the more enrolled students, the more test takers. No corelation otherwise, as expected.

# %%
# Scatter plot
fig, ax = plt.subplots(figsize=(16,9))
# Define values
x = final_df['pct_of_bm']
y = final_df['pct_part']

#make the plot
ax.scatter(x,y,color='orange')
         
ax.set_xlabel('% of benchmark',size=20, **{'fontname':'Helvetica'})  # https://stackoverflow.com/questions/21321670/how-to-change-fonts-in-matplotlib-python
ax.set_ylabel('participation rate',size=20, **{'fontname':'Helvetica'})
ax.tick_params(axis='both',labelsize=16)
plt.savefig('scatter.png')

# %% [markdown]
# Slight non-linear correlation between participation rates and test results. It appears higher participation rates cause a slight decline in test results.

# %%
# Box plot
fig, ax = plt.subplots(figsize=(16,9))
ax.box = final_df.boxplot(column=['pct_of_bm'], return_type='axes');
ax.set_xlabel('% of benchmark', size=24, labelpad=16);

# %% [markdown]
# With few data outliers, the quartiles are almost identical meaning the distribution is close to normal.

# %%
# Histogram
fig, ax = plt.subplots(figsize=(16,9))
ax.hist = final_df['pct_of_bm'].hist(bins=50)

# %%
# bar chart

# Bar Graph

# Setup plot figure fig = white space 
fig, ax = plt.subplots(figsize=(16,128))

# define plotting values
temp_df = final_df[['district_name', 'pct_of_bm']].sort_values('pct_of_bm', ascending=True)

# Get name of categories
x = list(temp_df['pct_of_bm']) 
y = list(temp_df.district_name.values)

# make BAr graph
ax.bar(x,y)

# formatting
# Lable Plot
ax.set_xlabel('% of benchmark', size=24, labelpad=16)
ax.set_ylabel('District Name', size=24, labelpad=16)
ax.tick_params(axis='both', labelsize=12)
plt.savefig('all_vs_bm.png')

# %% [markdown]
# Produce a Bottom 20 list:

# %%
fig, ax = plt.subplots(figsize=(20,9))

temp_df = final_df[['district_name', 'pct_of_bm']].sort_values('pct_of_bm', ascending=True).head(20) #elec = elec[elec['temp'] >= 15]

# Get name of categories
y = list(temp_df['district_name']) 
x = list(temp_df['pct_of_bm'])

# make BAr graph
ax.bar(x,y)

# formatting
# Lable Plot
ax.set_xlabel('% of benchmark', size=24, labelpad=16)
ax.set_ylabel('District Name', size=24, labelpad=16)
ax.tick_params(axis='both', labelsize=16)
plt.savefig('20_below_bm.pdf')

# %%
list(temp_df['district_name'])
# Out:
# ['Golden Plains Unified',
#  'Inyo County Office of Education',
#  'Williams Unified',
#  'Tulelake Basin Joint Unified',
#  'Firebaugh-Las Deltas Unified',
#  'Reef-Sunset Unified',
#  'Cloverdale Unified',
#  'Ravenswood City Elementary',
#  'SBE - Academia Avance Charter',
#  'San Pasqual Valley Unified',
#  'Mendota Unified',
#  'Compton Unified',
#  'SBE - The School of Arts and Enterprise',
#  'Lindsay Unified',
#  'Cutler-Orosi Joint Unified',
#  'Borrego Springs Unified',
#  'Le Grand Union High',
#  'Farmersville Unified',
#  'South Monterey County Joint Union High',
#  'Gonzales Unified']

# %% [markdown]
# Average participation rate:

# %%
# https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/
avg_pct = final_df[['district_name','pct_part']]
mean = avg_pct['pct_part'].mean()
avg_pct['var_to_mean'] = mean - avg_pct['pct_part']
avg_pct['colors'] = ['red' if x < 0 else 'green' for x in avg_pct['var_to_mean']]
avg_pct = avg_pct.sort_values('var_to_mean', ascending=True)
avg_pct = avg_pct.reset_index(drop=True)

# Draw plot
plt.figure(figsize=(14,10), dpi= 80)
plt.hlines(y=avg_pct.index, xmin=0, xmax=avg_pct.var_to_mean, color=avg_pct.colors, alpha=0.4, linewidth=5)

# Decorations
plt.gca().set(ylabel='District Name', xlabel='Variance to average % participation')
plt.title('Variance to average participation rate', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)
plt.savefig('var_to_mean.png')
# Out:
# <ipython-input-65-4b39a6df89e6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_pct['var_to_mean'] = mean - avg_pct['pct_part']
# <ipython-input-65-4b39a6df89e6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg_pct['colors'] = ['red' if x < 0 else 'green' for x in avg_pct['var_to_mean']]

# %% [markdown]
# Bottom 20 by participation rate:

# %%
avg_pct.tail(20)
# Out:
#                               district_name  pct_part  var_to_mean colors
# 391                           Ukiah Unified  0.108571     0.159265  green
# 392                         Morongo Unified  0.104425     0.163411  green
# 393                 Borrego Springs Unified  0.100324     0.167512  green
# 394                     Oroville Union High  0.098848     0.168988  green
# 395    Riverside County Office of Education  0.097902     0.169934  green
# 396               Spencer Valley Elementary  0.090301     0.177535  green
# 397   Santa Cruz County Office of Education  0.090067     0.177769  green
# 398                         Barstow Unified  0.088832     0.179003  green
# 399                Acton-Agua Dulce Unified  0.088328     0.179508  green
# 400                 Julian Union Elementary  0.086957     0.180879  green
# 401                 Mountain Empire Unified  0.086257     0.181579  green
# 402   Orange County Department of Education  0.084746     0.183090  green
# ...

# %%
## Conclusions and Recommendations

# %%
list(temp_df['district_name'])
# Out:
# ['Golden Plains Unified',
#  'Inyo County Office of Education',
#  'Williams Unified',
#  'Tulelake Basin Joint Unified',
#  'Firebaugh-Las Deltas Unified',
#  'Reef-Sunset Unified',
#  'Cloverdale Unified',
#  'Ravenswood City Elementary',
#  'SBE - Academia Avance Charter',
#  'San Pasqual Valley Unified',
#  'Mendota Unified',
#  'Compton Unified',
#  'SBE - The School of Arts and Enterprise',
#  'Lindsay Unified',
#  'Cutler-Orosi Joint Unified',
#  'Borrego Springs Unified',
#  'Le Grand Union High',
#  'Farmersville Unified',
#  'South Monterey County Joint Union High',
#  'Gonzales Unified']

# %%
list(avg_pct['district_name'].tail(20))
# Out:
# ['Ukiah Unified',
#  'Morongo Unified',
#  'Borrego Springs Unified',
#  'Oroville Union High',
#  'Riverside County Office of Education',
#  'Spencer Valley Elementary',
#  'Santa Cruz County Office of Education',
#  'Barstow Unified',
#  'Acton-Agua Dulce Unified',
#  'Julian Union Elementary',
#  'Mountain Empire Unified',
#  'Orange County Department of Education',
#  'Lompoc Unified',
#  'Tulare County Office of Education',
#  'Inyo County Office of Education',
#  'San Joaquin County Office of Education',
#  'Lucerne Valley Unified',
#  'Oro Grande',
#  'Dehesa Elementary',
#  'San Diego County Office of Education']

# %%
list_1 = list(temp_df['district_name'])
list_2 = list(avg_pct['district_name'].tail(20))
both = [name for name in list_1 if name in list_2]
both
# Out:
# ['Inyo County Office of Education', 'Borrego Springs Unified']

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
